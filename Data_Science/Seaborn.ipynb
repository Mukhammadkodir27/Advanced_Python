# %% [markdown]
# # Group By

# %%
import pandas as pd
import numpy as np
from pathlib import Path

csv_path = Path('data/titanic.csv')
titanic = pd.read_csv(csv_path)

# %%
gr_by_sex = titanic.groupby('Sex')
gr_by_sex.groups
# Out:
# {'female': [1, 2, 3, 8, 9, 10, 11, 14, 15, 18, 19, 22, 24, 25, 28, 31, 32, 38, 39, 40, 41, 43, 44, 47, 49, 52, 53, 56, 58, 61, 66, 68, 71, 79, 82, 84, 85, 88, 98, 100, 106, 109, 111, 113, 114, 119, 123, 128, 132, 133, 136, 140, 141, 142, 147, 151, 156, 161, 166, 167, 172, 177, 180, 184, 186, 190, 192, 194, 195, 198, 199, 205, 208, 211, 215, 216, 218, 229, 230, 233, 235, 237, 240, 241, 246, 247, 251, 254, 255, 256, 257, 258, 259, 264, 268, 269, 272, 274, 275, 276, ...], 'male': [0, 4, 5, 6, 7, 12, 13, 16, 17, 20, 21, 23, 26, 27, 29, 30, 33, 34, 35, 36, 37, 42, 45, 46, 48, 50, 51, 54, 55, 57, 59, 60, 62, 63, 64, 65, 67, 69, 70, 72, 73, 74, 75, 76, 77, 78, 80, 81, 83, 86, 87, 89, 90, 91, 92, 93, 94, 95, 96, 97, 99, 101, 102, 103, 104, 105, 107, 108, 110, 112, 115, 116, 117, 118, 120, 121, 122, 124, 125, 126, 127, 129, 130, 131, 134, 135, 137, 138, 139, 143, 144, 145, 146, 148, 149, 150, 152, 153, 154, 155, ...]}

# %%
l = list(gr_by_sex)
# l

# %%
len(l)
# Out:
# 2

# %%
# l[0]

# %%
l[0][0]
# Out:
# 'female'

# %%
l[1][0]
# Out:
# 'male'

# %%
# l[0][1]

# %%
# for element in gr_by_sex:
#     print(element[1])

# %% [markdown]
# ### Splitting with many Keys

# %%
split = titanic.groupby(by = ['Sex', 'Survived'])
for s in split:
    print(s[0])
# Out:
# ('female', 0)
# ('female', 1)
# ('male', 0)
# ('male', 1)

# %% [markdown]
# # Arithmetic Operations

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
mean = round(titanic.Age.mean(), 1)
titanic['Age'] = titanic['Age'].fillna(mean)

# %%
titanic.SibSp + titanic.Parch
# Out:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 886    0
# 887    0
# 888    3
# 889    0
# 890    0
# Length: 891, dtype: int64

# %%
titanic['No_Relat'] = titanic.SibSp.add(titanic.Parch)
#.sub  col.sub(col)
#.mul 
#.div
# two cols are * or // together to form another new col

# %%
# Out:
# No_Relat
# 0     537
# 1     161
# 2     102
# 3      29
# 5      22
# 4      15
# 6      12
# 10      7
# 7       6
# Name: count, dtype: int64

# %% [markdown]
# # Advanced Statistical Visualization with Seaborn

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
titanic['Pclass'] = titanic['Pclass'].astype(str)  # converting to str

# %%
plt.figure(figsize = (4, 3))
sns.countplot(data = titanic, x='Sex') # y = "Sex" -- vertical
# countplot shows the number of observations in each categorical bin using bars
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
plt.figure(figsize = (4, 3))
sns.countplot(data = titanic, x='Sex', hue='Survived')  # pclass is str
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
plt.figure(figsize = (8, 5))
sns.set(font_scale=1.5, palette='viridis')
sns.countplot(data = titanic, x='Sex', hue='Pclass')
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %% [markdown]
# # Categorical Plots

# %%
plt.figure(figsize=(7, 4.5))
sns.set(font_scale=1.5)
sns.stripplot(data=titanic, x='Sex', y='Age', jitter = True, hue='Survived', dodge=True)
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
plt.figure(figsize=(8, 5))
sns.set(font_scale=1.5)
sns.swarmplot(data=titanic, x='Sex', y='Age', hue='Pclass', dodge=True)
# Out:
# C:\Users\khali\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 20.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\khali\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 6.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='Sex', ylabel='Age'>
# C:\Users\khali\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 22.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\khali\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 10.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
plt.figure(figsize=(8, 5))
sns.set(font_scale=1.5)
sns.violinplot(data=titanic, x='Sex', y='Age', hue='Pclass', dodge=True)
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
plt.figure(figsize=(8, 5))
sns.set(font_scale=1.5)
sns.violinplot(data=titanic, x='Sex', y='Age', hue='Pclass', dodge=True)
sns.swarmplot(data=titanic, x='Sex', y='Age', hue='Pclass', dodge=True, color='black')
# Out:
# C:\Users\khali\AppData\Local\Temp\ipykernel_9248\174333359.py:4: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.swarmplot(data=titanic, x='Sex', y='Age', hue='Pclass', dodge=True, color='black')
# C:\Users\khali\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 22.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\khali\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 10.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
plt.figure(figsize=(8, 5))
sns.set(font_scale=1.5)
sns.violinplot(data=titanic, x='Pclass', y='Age', hue='Sex', dodge=True, split=True)
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
plt.figure(figsize=(8, 5))
sns.set(font_scale=1.5)
sns.barplot(data=titanic, x='Pclass', y='Age', hue='Sex', dodge=True)
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
plt.figure(figsize=(8, 5))
sns.set(font_scale=1.5)
sns.pointplot(data=titanic, x='Pclass', y='Age', hue='Sex', dodge=True)
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# # Joinplots / Regression

# %%
#plt.figure(figsize=(8, 5))
sns.set(font_scale=1)
sns.jointplot(data=titanic, x='Age', y='Fare', height = 6, kind = 'reg') #'kde', 'scatter'
# by 'reg' we can draw regression line
# up and right side you can see frequency distribution

# %%
sns.set(font_scale=1.5)
sns.lmplot(data=titanic, x='Age', y='Fare', aspect = 1, height = 6, col = 'Sex')
# sns.lmplot(data=titanic, x='Age', y='Fare', aspect = 1, height = 6, row = 'Sex')
# sns.lmplot(data=titanic, x='Age', y='Fare', aspect = 1, height = 6, hue = 'Sex')

# %%
sns.set(font_scale=1.5)
sns.lmplot(data=titanic, x='Age', y='Survived', aspect=1, height=6, col='Sex', logistic=True)

# %%
sns.set(font_scale=1.5)
sns.lmplot(data=titanic, x='Age', y='Survived', aspect=1, height=6, col='Pclass', logistic=True)

# %% [markdown]
# # Matrixplots / Heatmaps

# %%
pd.crosstab(titanic.Sex, titanic.Pclass)
# Out:
# Pclass    1    2    3
# Sex
# female   94   76  144
# male    122  108  347

# %%
plt.figure(figsize=(8, 6))
sns.set(font_scale=1.4)
sns.heatmap(pd.crosstab(titanic.Sex, titanic.Pclass), annot=True, fmt='d', cmap='Reds', vmax=150)
# you can set vmax = n to set a limit, here above 150 is dark red
# Out:
# <Axes: xlabel='Pclass', ylabel='Sex'>

# %%
# plt.figure(figsize=(8, 6))
# sns.set(font_scale=1.4)
# sns.heatmap(titanic.corr(), annot=True, cmap='Reds')

# %%
rcParams.update({"figure.autolayout":True, "axes.titlepad": 20})
plt.rcParams['figure.figsize'] = (20, 10)

title_font = {
    'family':'times new roman', 
    'color': 'darkblue',
    'weight': 'normal',
    'size': 24,
}
labels_font = {
    'family': 'consolas',
    'color': 'darkred',
    'weight': 'normal',
    'size': 20,
}

fig = plt.figure()
subplot = fig.add_subplot(1, 1, 1)
acquisition_year.plot(ax=subplot, rot=45, logy=True, grid=True) #rot will rotate years position

subplot.set_xlabel('Acquisition Year', fontdict=labels_font, labelpad=10)
subplot.set_ylabel('Artworks Acquired', fontdict=labels_font, labelpad=10)

subplot.set_title('Tate Gallery Acquisitions', fontdict=title_font)

plt.xticks(fontsize=16)
plt.yticks(fontsize=18)

subplot.locator_params(nbins=50, axis='x') 

fig.savefig('user_info/plot1.png')
fig.savefig('user_info/plot2.svg')
